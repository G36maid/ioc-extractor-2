# %%
# !pip install datasets transformers seqeval wandb
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
path = '/content/drive/MyDrive/model_training'
os.chdir(path)

# %%
import wandb
wandb.login()
# wandb.init(project="report_to_stix"
#   , group="fine-tune", config={'api_key':'429f12df59ecaf79b48858930860fb4ac921c2dd'})
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: cynthiachan. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### model_name_or_path 包含以下四種
# 1. bert-base-cased
# 2. roberta-base
# 3. google/electra-base-discriminator
# 4. microsoft/deberta-base
#
# ### output_dir 需要再設定掛接雲端硬碟後的位置

# %%
# !python run_ner.py \
  --model_name_or_path google/electra-base-discriminator \
  --dataset_name cynthiachan/FeedRef2022 \
  --output_dir /content/training \
  --do_train \
  --do_eval \
  --return_entity_level_metrics TRUE \
  --label_all_tokens TRUE \
  --evaluation_strategy steps \
  --num_train_epochs 3 \
  --save_total_limit 1 \
  --report_to wandb \
  --run_name test_run \
  --load_best_model_at_end TRUE \
  --save_steps 500 \
  --disable_tqdm TRUE
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: cynthiachan. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/drive/MyDrive/model_training/wandb/run-20221113_081345-2380socc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run toasty-totem-154
# wandb: ⭐️ View project at https://wandb.ai/cynthiachan/report_to_stix
# ...
